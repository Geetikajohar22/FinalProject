# %% [markdown]
# # FinalProject For Learning Tools For Data Science

# %% [markdown]
# __Introduction__ Data Science is a combination of multiple disciplines that uses statistics, data analysis, and machine learning to analyze data and to extract knowledge from it.
# _It is about data gathering, analysis,decision-making, finding patterns in data and make future predictions._

# %% [markdown]
# __Top Data Science Programming Languages are:__
#
#    1. Python
#    2. R
#    3. Scala
#    4. Julia
#    5. Java
#    6. Matlab
#    7. SAS
#    8. SQL
#    9. Perl
#    10. Stata

# %% [markdown]
#  __Top data science libraries for Python (the most common data science language used) are :__
#
#    1. TensorFlow
#    2. NumPy
#    3. SciPy
#    4. Pandas
#    5. Matplotlib
#    6. Keras
#    7. Scrapy
#    8. SciKit-Learn
#    9. Pytorch
#    10. Seaborn
#    11. BeautifulSoup
#    12. LightGBM
#    13. Bob
#    14. PyBrain
#    15. Chainer
#    16. pydot
#    17. Plotly
#    18. Ramp
#    19. NuPIC
#    20. Bokeh

# %% [markdown]
# __Different Data Science tools are:__
#
#    |Tools name|     |      |
#    |:--------:  |:---:|:----:|
#    |Apache Spark|IBM SPSS|Cloud|
#    |:----------:|:---:|:--:|
#    |Jupyter Notebook|MLflow|AirFlow|
#    |:--:|:--:|:--:|
#    |NoSQL| SQL| DataBricks|
#    |:--:|:--:|:--:|
#    |Docker|VisualStudio Code| Weka|

# %% [markdown]
# __Evaluating Basic Airthemetic Expressions__

# %%
val1 = 25.5
val2 = 65.5
val3 = 4

sum = float(val1) + float(val2)

print("The sum of given numbers is: ", sum)

multiply= sum * (val3)

print("The multiplication of given number is", multiply)
# Out:
# The sum of given numbers is:  91.0
# The multiplication of given number is 364.0

# %%
total_minutes = 220

hours = total_minutes // 60

minutes = total_minutes % 60

time = "{}:{}".format(hours, minutes)

print(time)
# Out:
# 3:40

# %% [markdown]
# __Objectives for data scientist:__
#   -  To have a curiousity about data science.
#    -   To Study the tools, languages and libraries of data science.
#        -  To Visualize and analyze the data.

# %% [markdown]
# __Geetika Johar__
# _Research Scholar_
